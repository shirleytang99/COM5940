# %%
import requests
import csv
from bs4 import BeautifulSoup
quote_page = requests.get('http://www.alicecatherine.com/blog/') 
soup = BeautifulSoup(quote_page.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>Blog – Alice Catherine</title>
# <link href="//cdn.jsdelivr.net" rel="dns-prefetch"/>
# <link href="//use.fontawesome.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/www.alicecatherine.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.9.9"}};
# ...

# %%
import requests
import csv
from bs4 import BeautifulSoup

quote_page = requests.get('http://www.alicecatherine.com/blog/') 
soup = BeautifulSoup(quote_page.content,'html.parser')
data = []
for article in soup.find_all('div',class_='cell'):
     url = article.div.h3.a.get('href') 
     post_date = article.div.time.text
     data.append((url, post_date))

with open('assignment2.csv', 'w') as csv_file: 
     writer = csv.writer(csv_file)
     header = ['url','post date'] 
     writer.writerow(header)
     for url, post_date in data: writer.writerow([url, post_date])

# %%
# %%time
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup 
from time import sleep
from random import randint 
from time import time

# quote_page = requests.get('http://www.alicecatherine.com/blog/')
# soup = BeautifulSoup(quote_page.text,'html.parser')

header = ['title','url','categories','post date']
data = []
 
for article in soup.find_all("div", attrs={"class":"cell"}):
# for article in soup.find_all('div',class_='cell'):
         title = article.div.h3.a.text.encode('utf-8').strip()
         decoded_title = title.decode('utf-8')
         url = article.div.h3.a.get('href') 
         categories = article.div.nav.a.text.encode('utf-8').strip()
         decoded_categories = categories.decode('utf-8')
         post_date = article.div.time.text
         print(decoded_title)
         print(url)
         print(decoded_categories)
         print(post_date)
         data.append((decoded_title, url, decoded_categories, post_date))

df = pd.DataFrame(data, 
 columns = header)
df.to_csv('assignment2_2.csv', sep='\t', encoding='utf-8')
# Out:
# A Love Letter
# http://www.alicecatherine.com/2019/02/14/a-love-letter/
# Inspiration
#
#                         February 14, 2019
# What Blogging Means To Me
# http://www.alicecatherine.com/2019/02/11/what-blogging-means-to-me/
# Inspiration
#
#                         February 11, 2019
# A Lesson In Layering Blazers
# http://www.alicecatherine.com/2019/02/06/layering-blazers-for-winter/
# Fashion
#
#                         February 6, 2019
# Back To Paris
# http://www.alicecatherine.com/2019/02/04/back-to-paris/
# Lifestyle
#
#                         February 4, 2019
# End Of January Updates…
# http://www.alicecatherine.com/2019/01/28/end-of-january-updates/
# Lifestyle
#
#                         January 28, 2019
# Staying True Amongst The Trends…
# http://www.alicecatherine.com/2019/01/26/staying-true-amongst-the-trends/
# Fashion
#
#                         January 26, 2019
# Letting Go & Living Differently
# ...
